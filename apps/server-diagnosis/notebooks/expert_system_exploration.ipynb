# %%
from random import choice
from experta import *

# %%
description_dictionary = {"overweight":"DETERMINED BY FORM - BMI above 25",
"active":"DETERMINED BY FORM - excercise 3x+ a week",
"above_50":"DETERMINED BY FORM - above 50 years old",
"racially_african": "DETERMINED BY FORM - racial identity", 
"hypertension":"DETERMINED BY FORM - below 90/60",
"hypotension":"DETERMINED BY FORM - above 140/90",
"smoking":"are you an active smoker?",
"high_cholesterol": "have you ever get diagnosed to have high cholesterol level?",
"diabetes":"have you ever get diagnosed to have diabetes?",
"blood_clotting_disorder":"have you ever get diagnosed to have blood clotting disorder?",
"kidney_disease":"have you ever get diagnosed to have kidney diease?",
"chest_pains":"do you have any chest pains recently?",
"breathlessness":"do you feel frequent breathlessness recently?",
"nausea":"do you frequently feel nauseous recently?",
"faintings":"did you faint recently?",
"fatigue":"do you frequently feel fatigued recently?",
"swollen_ankles":"do you have swollen ankles?",
"drastic_weight_changes":"did you went through a drastic changes in weight recently?", 
"bloating":"do you frequently feel bloated recently?",
"loss_of_appetite":"do you frequently lost appetite recently?",
"dizziness_confusion":"do you frequently get dizziness and confusion recently?",
"palpitations": "do you frequently have abnormally rapid or irregular beat of heart recently? (palpitation)",
"atrial_fibrillation":"do you frequently have abnormally slow, fast, or irregular beat of heart recently? (atrial_fibrillation)",
"sudden_headache":"do you frequently suffer sudden headaches recently?",
"sudden_lossofvision":"do you suffer sudden loss of vision recently?",
"face_dropping":"do you suffer from face dropping recently?",
"numbness":"do you suffer from numbness recently?",
"speech_problem":"do you have speech problem recently?",
"leg_pain_cramping":"do you suffer from leg cramping or pain recently?",
"burning_aching_toes":"do you suffer from burning or aching toes recently?",
"cool_feet_skin":"do you frequently feel coldness on your feet skin recently?",
"redness_colorchanges_skin":"do you suffer from redness or other form of color changes on your skin recently?",
"back_pain":"do you suffer from back pain recently?",
"coughing":"do you frequently cough recently?",
"hoarseness":"do you frequently suffer from weak and scratchy voice recently? (hoarseness)",
"tenderness_pain_chest":"do you suffer from chest pain or tenderness recently?",
"sharp_sudden_pain_upperback":"do you suffer from sudden sharp pain in the upper back that spreads downward recently?",
"pain_chest_jaw_neck_arms":"do you suffer from any form of pain or aching in your chest, jaw, neck, or arms recently?",
"loss_of_consciousness":"did you lose your consciousness recently?",
"difficulty_breathing":"did you suffer from any form of breathing difficulty recently?",
"trouble_swalowwing_food":"did you have any trouble swallowing food recently?",
"deep_constant_belly_pain":"do you suffer from deep and constant belly pains recently?",
"family_history_coronaryheartdisease":"do your family have any history of coronary heart disease?",
"personal_family_history_blood_bloodvesseldisease":"do you have any personal or family history of any blood or blood vessel disease?"
}

# %%
questionare_dictionary_sample={
"blood_clotting_disorder":False,
"kidney_disease":False,
"chest_pains":False,
"breathlessness":False,
"nausea":False,
"faintings":False,
"fatigue":False,
"swollen_ankles":False,
"drastic_weight_changes":False, 
"bloating":False,
"loss_of_appetite":False,
"dizziness_confusion":False,
"palpitations":False,
"atrial_fibrillation":False,
"sudden_headache":False,
"sudden_lossofvision":False,
"face_dropping":False,
"numbness":False,
"speech_problem":False,
"leg_pain_cramping":False,
"burning_aching_toes":False,
"cool_feet_skin":False,
"redness_colorchanges_skin":False,
"back_pain":False,
"coughing":False,
"hoarseness":False,
"tenderness_pain_chest":False,
"sharp_sudden_pain_upperback":False,
"pain_chest_jaw_neck_arms":False,
"loss_of_consciousness":False,
"difficulty_breathing":False,
"trouble_swalowwing_food":False,
"deep_constant_belly_pain":False,
"family_history_coronaryheartdisease":False,
"personal_family_history_blood_bloodvesseldisease":False
}

# %%
class Symptom(Fact):
    pass
class CVDExpertSystem(KnowledgeEngine):
    def diagnose(self, questionare_dictionary, form_dictionary):
        self.reset()
        _overweight = ((form_dictionary["weight"]/((form_dictionary["height"]/100)**2))>25)
        _active = form_dictionary["active"]==1
        _above_50 = form_dictionary["age"]>50
        _hypotension = (form_dictionary["ap_hi"]<90)|(form_dictionary["ap_lo"]<60)
        _hypertension = (form_dictionary["ap_hi"]>140)|(form_dictionary["ap_lo"]>90)
        _smoking = form_dictionary["smoke"]==1
        _high_cholesterol = form_dictionary["cholesterol"]>1
        _diabetes = form_dictionary["gluc"]>1
        _racially_african = form_dictionary["racial_identity"]=="african"
        self.declare(Fact(overweight = _overweight))
        self.declare(Fact(active = _active))
        self.declare(Fact(above_50 = _above_50))
        self.declare(Fact(hypotension = _hypotension))
        self.declare(Fact(hypertension = _hypertension))
        self.declare(Fact(smoking = _smoking))
        self.declare(Fact(high_cholesterol = _high_cholesterol))
        self.declare(Fact(diabetes = _diabetes))
        self.declare(Fact(racially_african = _racially_african))
        self.declare(Fact(blood_clotting_disorder = questionare_dictionary["blood_clotting_disorder"]))
        self.declare(Fact(kidney_disease = questionare_dictionary["kidney_disease"]))
        self.declare(Fact(chest_pains = questionare_dictionary["chest_pains"]))
        self.declare(Fact(breathlessness = questionare_dictionary["breathlessness"]))
        self.declare(Fact(nausea = questionare_dictionary["nausea"]))
        self.declare(Fact(faintings = questionare_dictionary["faintings"]))
        self.declare(Fact(fatigue = questionare_dictionary["fatigue"]))
        self.declare(Fact(swollen_ankles = questionare_dictionary["swollen_ankles"]))
        self.declare(Fact(drastic_weight_changes = questionare_dictionary["drastic_weight_changes"]))
        self.declare(Fact(bloating = questionare_dictionary["bloating"]))
        self.declare(Fact(loss_of_appetite = questionare_dictionary["loss_of_appetite"]))
        self.declare(Fact(dizziness_confusion = questionare_dictionary["dizziness_confusion"]))
        self.declare(Fact(palpitations = questionare_dictionary["palpitations"]))
        self.declare(Fact(atrial_fibrillation = questionare_dictionary["atrial_fibrillation"]))
        self.declare(Fact(sudden_headache = questionare_dictionary["sudden_headache"]))
        self.declare(Fact(sudden_lossofvision = questionare_dictionary["sudden_lossofvision"]))
        self.declare(Fact(face_dropping = questionare_dictionary["face_dropping"]))
        self.declare(Fact(numbness = questionare_dictionary["numbness"]))
        self.declare(Fact(speech_problem = questionare_dictionary["speech_problem"]))
        self.declare(Fact(leg_pain_cramping = questionare_dictionary["leg_pain_cramping"]))
        self.declare(Fact(burning_aching_toes = questionare_dictionary["burning_aching_toes"]))
        self.declare(Fact(cool_feet_skin = questionare_dictionary["cool_feet_skin"]))
        self.declare(Fact(redness_colorchanges_skin = questionare_dictionary["redness_colorchanges_skin"]))
        self.declare(Fact(back_pain = questionare_dictionary["back_pain"]))
        self.declare(Fact(coughing = questionare_dictionary["coughing"]))
        self.declare(Fact(hoarseness = questionare_dictionary["hoarseness"]))
        self.declare(Fact(tenderness_pain_chest = questionare_dictionary["tenderness_pain_chest"]))
        self.declare(Fact(sharp_sudden_pain_upperback = questionare_dictionary["sharp_sudden_pain_upperback"]))
        self.declare(Fact(pain_chest_jaw_neck_arms = questionare_dictionary["pain_chest_jaw_neck_arms"]))
        self.declare(Fact(loss_of_consciousness = questionare_dictionary["loss_of_consciousness"]))
        self.declare(Fact(difficulty_breathing = questionare_dictionary["difficulty_breathing"]))
        self.declare(Fact(trouble_swallowing_food = questionare_dictionary["trouble_swallowing_food"]))
        self.declare(Fact(deep_constant_belly_pain = questionare_dictionary["deep_constant_belly_pain"]))
        self.declare(Fact(family_history_coronaryheartdisease = questionare_dictionary["family_history_coronaryheartdisease"]))
        self.declare(Fact(personal_family_history_blood_bloodvesseldisease = questionare_dictionary["personal_family_history_blood_bloodvesseldisease"]))
        self.run()
        return self.symptoms_probability_dictionary
    
    symptoms_probability_dictionary = {"coronary_heart_disease":0, "stroke":0, "peripheral_arterial_disease":0, "thoracic_aortic_aneurysms":0, "abdominal_aortic_aneurysm":0}

    #coronary heart disease 
    #possible -> smoke, hypertension, high cholesterol, not active, diabetes, overweight, history of chd
    @Rule(Fact(smoking = True)| Fact(hypertension = True) | Fact(high_cholesterol = True) | Fact(active = False) | Fact(diabetes = True) | Fact(overweight = True) | Fact(family_history_coronaryheartdisease = True), salience = 11)
    def possible_coronary_heart_disease(self):
        print(1)
        self.symptoms_probability_dictionary["coronary_heart_disease"] = 0.1
        
    #probable -> angina -> chestpain, breathless, nausea, fainting
    @Rule(AND(Fact(chest_pains = True), Fact(breathlessness=True), Fact(nausea = True), Fact(faintings = True)), salience = 10)
    def probable_coronary_heart_disease(self):
        print(2)
        self.facts 
        self.symptoms_probability_dictionary["coronary_heart_disease"] = 0.5
        
    #confirmed -> sign of heart attack/failure
    #persistent coughing or wheezing, changes in weight, bloating, loss of apetite, diziness and confusion, palpitation
    @Rule(Fact(breathlessness=True), Fact(fatigue = True), Fact(swollen_ankles = True), Fact(coughing = True), Fact(palpitations = True), salience = 9)
    def confirmed_coronary_heart_disease(self):
        print(3)
        self.symptoms_probability_dictionary["coronary_heart_disease"] = 0.9

    #stroke

    #possible -> overweight, smoke, alcohol, high cholesterol, hypertension, diabetes, artrial fib
    @Rule(Fact(overweight = True) | Fact(smoking = True) | Fact(high_cholesterol = True) | Fact(hypertension = True) | Fact(diabetes = True) | Fact(atrial_fibrillation = True), salience = 8)
    def possible_stroke(self):
        print(4)
        self.symptoms_probability_dictionary["stroke"] = 0.1
    
    #probable -> sudden severe headache, dizziness confusion loss balance, loss vision , numbness
    @Rule(Fact(sudden_headache = True), Fact(dizziness_confusion = True), Fact(sudden_lossofvision = True), Fact(numbness = True), salience = 7)
    def probable_stroke(self):
        print(5)
        self.symptoms_probability_dictionary["stroke"] = 0.5

    #confirmed -> face drooping, arm weakness/numbness, speech problem
    @Rule(Fact(face_dropping = True), Fact(numbness = True), Fact(speech_problem = True), salience = 6)
    def confirmed_stroke(self):
        print(6)
        self.symptoms_probability_dictionary["stroke"] = 0.9
        
    #peripheral arterial disease
    
    #possible -> smoke, diabetes, 50+, african ethnicity, familial history of blood, hypertension, high cholesterol, bloodcloot, kidney disease
    @Rule(Fact(smoking = True) | Fact(diabetes = True) | Fact(above_50 = True) | Fact(racially_african = True) | Fact(personal_family_history_blood_bloodvesseldisease = True) | Fact(blood_clotting_disorder = True) | Fact(kidney_disease = True), salience = 5)
    def possible_peripheral_arterial_disease(self):
        print(7)
        self.symptoms_probability_dictionary["peripheral_arterial_disease"] = 0.1

    #probable -> leg pain cramp, toe ache, cool skin toe, redness, sore
    @Rule(Fact(leg_pain_cramping = True), Fact(burning_aching_toes = True), Fact(cool_feet_skin = True), Fact(redness_colorchanges_skin = True), salience = 4)
    def probable_peripheral_arterial_disease(self):
        print(8)
        self.symptoms_probability_dictionary["peripheral_arterial_disease"] = 0.5
        
    #Thoracic aortic aneurysms
    
    #possible -> back pain, cough, hoarseness, breathe, tender chest
    @Rule(Fact(back_pain = True) | Fact(coughing = True) | Fact(hoarseness = True) | Fact(difficulty_breathing = True) | Fact(tenderness_pain_chest = True), salience = 3)
    def possible_thoracic_aortic_aneurysms(self):
        print(9)
        self.symptoms_probability_dictionary["thoracic_aortic_aneurysms"] = 0.1


    #confirmed -> sharp sudden pain back, pain in chest jaw, diff breathe, hypotension, loss of con, short breath, trouble swallowing
    @Rule(Fact(sharp_sudden_pain_upperback = True), Fact(pain_chest_jaw_neck_arms = True), Fact(difficulty_breathing = True), Fact(hypertension = True), Fact(loss_of_consciousness = True), Fact(breathlessness=True), Fact(trouble_swallowing_food = True), salience = 2)
    def probable_thoracic_aortic_aneurysms(self):
        print(10)
        self.symptoms_probability_dictionary["thoracic_aortic_aneurysms"] = 0.9


    #abdominal aortic aneurysm
    
    #confirmed -> deep constant belly pain, back pain
    @Rule(Fact(deep_constant_belly_pain = True)& Fact(back_pain = True), salience = 1)
    def confirmed_abdominal_aortic_aneurysm(self):
        print(11)
        self.symptoms_probability_dictionary["abdominal_aortic_aneurysm"] = 0.9

# %%
test_input_form_dictionary = {"age":51,"gender":1,"height":155,"weight":120,"ap_hi":190,"ap_lo":80,"cholesterol":2,"gluc":2,"smoke":1,"alco":1,"active":1, "racial_identity":"african"}

# %%
test_input_questionare_dictionary={
"blood_clotting_disorder":True,
"kidney_disease":True,
"chest_pains":True,
"breathlessness":True,
"nausea":True,
"faintings":True,
"fatigue":True,
"swollen_ankles":True,
"drastic_weight_changes":True, 
"bloating":True,
"loss_of_appetite":True,
"dizziness_confusion":True,
"palpitations":True,
"atrial_fibrillation":True,
"sudden_headache":True,
"sudden_lossofvision":True,
"face_dropping":True,
"numbness":True,
"speech_problem":True,
"leg_pain_cramping":True,
"burning_aching_toes":True,
"cool_feet_skin":True,
"redness_colorchanges_skin":True,
"back_pain":True,
"coughing":True,
"hoarseness":True,
"tenderness_pain_chest":True,
"sharp_sudden_pain_upperback":True,
"pain_chest_jaw_neck_arms":True,
"loss_of_consciousness":True,
"difficulty_breathing":True,
"trouble_swallowing_food":True,
"deep_constant_belly_pain":True,
"family_history_coronaryheartdisease":True,
"personal_family_history_blood_bloodvesseldisease":True
}

# %%
engine = CVDExpertSystem()

def diagnose(questionare_dictionary, form_dictionary):
    engine.reset()
    _overweight = ((form_dictionary["weight"]/((form_dictionary["height"]/100)**2))>25)
    _active = form_dictionary["active"]==1
    _above_50 = form_dictionary["age"]>50
    _hypotension = (form_dictionary["ap_hi"]<90)|(form_dictionary["ap_lo"]<60)
    _hypertension = (form_dictionary["ap_hi"]>140)|(form_dictionary["ap_lo"]>90)
    _smoking = form_dictionary["smoke"]==1
    _high_cholesterol = form_dictionary["cholesterol"]>1
    _diabetes = form_dictionary["gluc"]>1
    _racially_african = form_dictionary["racial_identity"]=="african"
    engine.declare(Fact(overweight = _overweight))
    engine.declare(Fact(active = _active))
    engine.declare(Fact(above_50 = _above_50))
    engine.declare(Fact(hypotension = _hypotension))
    engine.declare(Fact(hypertension = _hypertension))
    engine.declare(Fact(smoking = _smoking))
    engine.declare(Fact(high_cholesterol = _high_cholesterol))
    engine.declare(Fact(diabetes = _diabetes))
    engine.declare(Fact(racially_african = _racially_african))
    engine.declare(Fact(blood_clotting_disorder = questionare_dictionary["blood_clotting_disorder"]))
    engine.declare(Fact(kidney_disease = questionare_dictionary["kidney_disease"]))
    engine.declare(Fact(chest_pains = questionare_dictionary["chest_pains"]))
    engine.declare(Fact(breathlessness = questionare_dictionary["breathlessness"]))
    engine.declare(Fact(nausea = questionare_dictionary["nausea"]))
    engine.declare(Fact(faintings = questionare_dictionary["faintings"]))
    engine.declare(Fact(fatigue = questionare_dictionary["fatigue"]))
    engine.declare(Fact(swollen_ankles = questionare_dictionary["swollen_ankles"]))
    engine.declare(Fact(drastic_weight_changes = questionare_dictionary["drastic_weight_changes"]))
    engine.declare(Fact(bloating = questionare_dictionary["bloating"]))
    engine.declare(Fact(loss_of_appetite = questionare_dictionary["loss_of_appetite"]))
    engine.declare(Fact(dizziness_confusion = questionare_dictionary["dizziness_confusion"]))
    engine.declare(Fact(palpitations = questionare_dictionary["palpitations"]))
    engine.declare(Fact(atrial_fibrillation = questionare_dictionary["atrial_fibrillation"]))
    engine.declare(Fact(sudden_headache = questionare_dictionary["sudden_headache"]))
    engine.declare(Fact(sudden_lossofvision = questionare_dictionary["sudden_lossofvision"]))
    engine.declare(Fact(face_dropping = questionare_dictionary["face_dropping"]))
    engine.declare(Fact(numbness = questionare_dictionary["numbness"]))
    engine.declare(Fact(speech_problem = questionare_dictionary["speech_problem"]))
    engine.declare(Fact(leg_pain_cramping = questionare_dictionary["leg_pain_cramping"]))
    engine.declare(Fact(burning_aching_toes = questionare_dictionary["burning_aching_toes"]))
    engine.declare(Fact(cool_feet_skin = questionare_dictionary["cool_feet_skin"]))
    engine.declare(Fact(redness_colorchanges_skin = questionare_dictionary["redness_colorchanges_skin"]))
    engine.declare(Fact(back_pain = questionare_dictionary["back_pain"]))
    engine.declare(Fact(coughing = questionare_dictionary["coughing"]))
    engine.declare(Fact(hoarseness = questionare_dictionary["hoarseness"]))
    engine.declare(Fact(tenderness_pain_chest = questionare_dictionary["tenderness_pain_chest"]))
    engine.declare(Fact(sharp_sudden_pain_upperback = questionare_dictionary["sharp_sudden_pain_upperback"]))
    engine.declare(Fact(pain_chest_jaw_neck_arms = questionare_dictionary["pain_chest_jaw_neck_arms"]))
    engine.declare(Fact(loss_of_consciousness = questionare_dictionary["loss_of_consciousness"]))
    engine.declare(Fact(difficulty_breathing = questionare_dictionary["difficulty_breathing"]))
    engine.declare(Fact(trouble_swallowing_food = questionare_dictionary["trouble_swallowing_food"]))
    engine.declare(Fact(deep_constant_belly_pain = questionare_dictionary["deep_constant_belly_pain"]))
    engine.declare(Fact(family_history_coronaryheartdisease = questionare_dictionary["family_history_coronaryheartdisease"]))
    engine.declare(Fact(personal_family_history_blood_bloodvesseldisease = questionare_dictionary["personal_family_history_blood_bloodvesseldisease"]))
    engine.run()
    return engine.symptoms_probability_dictionary

# %%
print(engine.diagnose(test_input_questionare_dictionary,test_input_form_dictionary))

#note : MASUKIN instance engine ke pkl -> load di main.
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 3
# 4
# 4
# 4
# 4
# 4
# 4
# 5
# 6
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 8
# 9
# 9
# 9
# 9
# 9
# 10
# 11
# {'coronary_heart_disease': 0.9, 'stroke': 0.9, 'peripheral_arterial_disease': 0.5, 'thoracic_aortic_aneurysms': 0.9, 'abdominal_aortic_aneurysm': 0.9}
